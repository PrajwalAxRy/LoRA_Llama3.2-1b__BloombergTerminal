# %%
import fitz  # PyMuPDF
from langchain.text_splitter import RecursiveCharacterTextSplitter
from colorama import Fore, Style
from pydantic import BaseModel
from typing import List
import json
import os

# %%
import sys
sys.path.append('..')

from scripts.llm_call import llm_call

# %%
class QAPair(BaseModel):
    question: str
    answer: str

# %%
class GeneratedData(BaseModel):
    generated: List[QAPair]

# %%
print("QAPair schema:", QAPair.model_json_schema())
print("\nGeneratedData schema:", GeneratedData.model_json_schema())
# Out:
# QAPair schema: {'properties': {'question': {'title': 'Question', 'type': 'string'}, 'answer': {'title': 'Answer', 'type': 'string'}}, 'required': ['question', 'answer'], 'title': 'QAPair', 'type': 'object'}
#
# GeneratedData schema: {'$defs': {'QAPair': {'properties': {'question': {'title': 'Question', 'type': 'string'}, 'answer': {'title': 'Answer', 'type': 'string'}}, 'required': ['question', 'answer'], 'title': 'QAPair', 'type': 'object'}}, 'properties': {'generated': {'items': {'$ref': '#/$defs/QAPair'}, 'title': 'Generated', 'type': 'array'}}, 'required': ['generated'], 'title': 'GeneratedData', 'type': 'object'}

# %%
source_pdf = "../data/bloomberg-terminal-1.pdf"
output_file = "../data/generated_qa_pairs.json"

generator_model = "ollama/llama3.1:8b"

print(f"Source PDF: {source_pdf}")
print(f"Output JSON: {output_file}")
print(f"Generator Model: {generator_model}")

# Check if source PDF exists
if os.path.exists(source_pdf):
    print(f"✅ Source PDF found!")
else:
    print(f"❌ Source PDF not found at {source_pdf}")
# Out:
# Source PDF: ../data/bloomberg-terminal-1.pdf
# Output JSON: ../data/generated_qa_pairs.json
# Generator Model: ollama/llama3.1:8b
# ✅ Source PDF found!

# %%
def create_prompt(data_chunk, num_records=5):
    """Create the prompt template for generating Q&A pairs"""
    return f"""You are an expert data curator assisting a machine learning engineer in creating a high-quality instruction tuning dataset. Your task is to transform 
    the provided data chunk into diverse question and answer (Q&A) pairs that will be used to fine-tune a language model for Bloomberg Terminal usage. 
    For each of the {num_records} entries, generate one or two well-structured questions that reflect different aspects of the information in the chunk. 
    Ensure a mix of longer and shorter questions. Each Q&A pair should be concise yet informative, capturing key insights from the data.
    Structure your output in JSON format, where each object contains 'question' and 'answer' fields. The JSON structure should look like this:
        "question": "Your question here...",
        "answer": "Your answer here..."
    Focus on creating clear, relevant, and varied questions that encourage the model to learn from diverse perspectives. Avoid any sensitive or biased 
    content, ensuring answers are accurate and neutral. You are allowed to use your own knowledge to add context and enhance the answers, but do not fabricate information.
    
    Data Chunk:
    ---
    {data_chunk}
    ---
    """

# %%
# Test the prompt function with sample data
sample_prompt = create_prompt("This is sample Bloomberg Terminal data about trading.", 3)
print("Sample prompt preview:")
print(sample_prompt + "...")
# Out:
# Sample prompt preview:
# You are an expert data curator assisting a machine learning engineer in creating a high-quality instruction tuning dataset. Your task is to transform
#     the provided data chunk into diverse question and answer (Q&A) pairs that will be used to fine-tune a language model for Bloomberg Terminal usage.
#     For each of the 3 entries, generate one or two well-structured questions that reflect different aspects of the information in the chunk.
#     Ensure a mix of longer and shorter questions. Each Q&A pair should be concise yet informative, capturing key insights from the data.
#     Structure your output in JSON format, where each object contains 'question' and 'answer' fields. The JSON structure should look like this:
#         "question": "Your question here...",
#         "answer": "Your answer here..."
#     Focus on creating clear, relevant, and varied questions that encourage the model to learn from diverse perspectives. Avoid any sensitive or biased
#     content, ensuring answers are accurate and neutral. You are allowed to use your own knowledge to add context and enhance the answers, but do not fabricate information.
#
#     Data Chunk:
#     ---
#     This is sample Bloomberg Terminal data about trading.
#     ---
#     ...

# %%
print(f"Step 1: Loading and extracting text from PDF...")

# Initialize empty string to store all text
full_text = ""

# Open PDF and extract text from all pages
with fitz.open(source_pdf) as doc:
    print(f"PDF has {len(doc)} pages")
    
    for page_num, page in enumerate(doc):
        page_text = page.get_text()
        full_text += page_text
        print(f"Extracted text from page {page_num + 1}: {len(page_text)} characters")

print(f"\nTotal text extracted: {len(full_text)} characters")
print(f"First 300 characters preview:\n{full_text[:300]}...")
# Out:
# Step 1: Loading and extracting text from PDF...
# PDF has 28 pages
# Extracted text from page 1: 131 characters
# Extracted text from page 2: 200 characters
# Extracted text from page 3: 1027 characters
# Extracted text from page 4: 758 characters
# Extracted text from page 5: 651 characters
# Extracted text from page 6: 596 characters
# Extracted text from page 7: 1254 characters
# Extracted text from page 8: 1885 characters
# Extracted text from page 9: 1790 characters
# Extracted text from page 10: 846 characters
# Extracted text from page 11: 550 characters
# Extracted text from page 12: 740 characters
# Extracted text from page 13: 1428 characters
# Extracted text from page 14: 581 characters
# Extracted text from page 15: 1340 characters
# Extracted text from page 16: 2100 characters
# Extracted text from page 17: 1216 characters
# Extracted text from page 18: 2310 characters
# Extracted text from page 19: 1317 characters
# Extracted text from page 20: 2445 characters
# Extracted text from page 21: 889 characters
# Extracted text from page 22: 1226 characters
# Extracted text from page 23: 1183 characters
# Extracted text from page 24: 2267 characters
# Extracted text from page 25: 2345 characters
# Extracted text from page 26: 1373 characters
# Extracted text from page 27: 524 characters
# Extracted text from page 28: 553 characters
#
# Total text extracted: 33525 characters
# First 300 characters preview:
# A Bloomberg Professional Services Offering
# A Bloomberg Professional Services Offering
#  Getting started on the
# Bloomberg Terminal.
# Contents
# 02	 Bloomberg Terminal
# 06	 Functions & securities
# 09	 Navigation
# 13	 Performing analysis
# 17	 Exporting data
# 20	 Bloomberg Market Concepts (BMC)
# 21	 Getting help...

# %%
print(f"Step 2: Splitting text into manageable chunks...")

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_text(full_text)
print(f"Total chunks created: {len(chunks)}")
print(f"First chunk preview:\n{chunks[0][:300]}...")
# Out:
# Step 2: Splitting text into manageable chunks...
# Total chunks created: 42
# First chunk preview:
# A Bloomberg Professional Services Offering
# A Bloomberg Professional Services Offering
#  Getting started on the
# Bloomberg Terminal.
# Contents
# 02	 Bloomberg Terminal
# 06	 Functions & securities
# 09	 Navigation
# 13	 Performing analysis
# 17	 Exporting data
# 20	 Bloomberg Market Concepts (BMC)
# 21	 Getting help...

# %%
print(f"{Fore.YELLOW}Step 3: Initializing dataset storage...{Style.RESET_ALL}")

# Initialize empty dataset dictionary
dataset = {}

print(f"Dataset initialized. Will process {len(chunks)} chunks.")
print(f"Expected to generate ~{len(chunks) * 5} Q&A pairs total (5 per chunk)")
# Out:
# Step 3: Initializing dataset storage...
# Dataset initialized. Will process 42 chunks.
# Expected to generate ~210 Q&A pairs total (5 per chunk)

# %%
print(f"{Fore.YELLOW}Step 4: Generating Q&A pairs for each chunk...{Style.RESET_ALL}")

for i, chunk in enumerate(chunks):
    print(f"{Fore.MAGENTA}\n--- Processing Chunk {i+1}/{len(chunks)} ---{Style.RESET_ALL}")
    print(f"Chunk length: {len(chunk)} characters")
    print(f"Chunk preview: {chunk[:150]}...")

    prompt = create_prompt(chunk, num_records=5)

    try:
        data = llm_call(
            model=generator_model,
            prompt=prompt,
            json_schema=json.dumps(GeneratedData.model_json_schema())
        )
        
        # Check if data was generated successfully
        if data and "generated" in data:
            dataset[i] = {
                "generated": data["generated"], 
                "context": chunk
            }
            print(f"{Fore.GREEN}✅ Successfully generated {len(data['generated'])} Q&A pairs for chunk {i+1}{Style.RESET_ALL}")
            
            # Show a preview of generated Q&A pairs
            for j, qa_pair in enumerate(data["generated"][:2]):  # Show first 2 pairs
                print(f"  Q{j+1}: {qa_pair.get('question', 'N/A')[:100]}...")
                print(f"  A{j+1}: {qa_pair.get('answer', 'N/A')[:100]}...")
        else:
            print(f"{Fore.RED}❌ Failed to generate Q&A for chunk {i+1}{Style.RESET_ALL}")
            
    except Exception as e:
        print(f"{Fore.RED}❌ Error processing chunk {i+1}: {str(e)}{Style.RESET_ALL}")
# Out:
# Step 4: Generating Q&A pairs for each chunk...
#
# --- Processing Chunk 1/42 ---
# Chunk length: 982 characters
# Chunk preview: A Bloomberg Professional Services Offering
# A Bloomberg Professional Services Offering
#  Getting started on the
# Bloomberg Terminal.
# Contents
# 02	 Bloomb...
# --- Calling model: ollama/llama3.1:8b ---
# {
#   "generated": [
#     {
#       "question": "What is the primary purpose of the Bloomberg for Education program?",
#       "answer": "Bloomberg for Education has been committed to helping universities and colleges incorporate the Bloomberg Terminal into their academic programs to better prepare students for the global job market."
#     },
#     {
#       "question": "How long has Bloomberg for Education been active in assisting universities and colleges with incorporating the Bloomberg Terminal?",
#       "answer": "For more than 20 years"
#     },
#     {
#       "question": "What benefits do students gain from using the Bloomberg Terminal in their academic programs?",
#       "answer": "Students get access to the same information platform used by leading decision makers in business, finance and government, bringing the real world of finance into the classroom."
#     },
#     {
#       "question": "Can you describe some key features of the Bloomberg Terminal?",
#       "answer": "The Bloomberg Terminal seamlessly integrates data, news, and analytics through a 24-hour global financial services system that provides transparent information"
#     }
#   ]
# }
# --- End of response ---
# ✅ Successfully generated 4 Q&A pairs for chunk 1
#   Q1: What is the primary purpose of the Bloomberg for Education program?...
#   A1: Bloomberg for Education has been committed to helping universities and colleges incorporate the Bloo...
#   Q2: How long has Bloomberg for Education been active in assisting universities and colleges with incorpo...
#   A2: For more than 20 years...
#
# --- Processing Chunk 2/42 ---
# Chunk length: 988 characters
# Chunk preview: The Bloomberg Terminal seamlessly integrates the very
# best in data, news and analytics. The Terminal is a 24-hour,
# global financial services system ...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [
#     {
#         "question": "What are the primary features of the Bloomberg Terminal?",
#         "answer": "The Bloomberg Terminal seamlessly integrates data, news, and analytics, providing transparent and reliable financial, economic, and government information covering all market sectors."
#     },
#     {
#         "question": "How does the Bloomberg keyboard assist in accessing information quickly on the Terminal?",
#         "answer": "The red stop keys, green action keys, and yellow market sector keys help access information swiftly, with the Menu key opening a menu of related functions and the Escape or Cancel key allowing exit from the current operation."
#     },
#     {
#         "question": "What is the purpose of the yellow market sector keys on the Bloomberg keyboard?",
#         "answer": "The yellow market sector keys enable loading securities and accessing market sector menus, providing easy navigation through various financial information sectors."
#     },
#     {
#         "question": "What types of data does the Bloomberg Terminal cover in its market data spanning over 20 years?",
#         "answer": "The Terminal features company financials, market data spanning more than 20 years, charts, statistics, a communications platform, and current news reports for comprehensive insights."
#     },
#     {
#         "question": "What is the primary intention of this guide on the Bloomberg Terminal?",
#         "answer": "This guide provides an overview to help users get started with using the powerful tool efficiently."
#     }
# ] }
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 2
#   Q1: What are the primary features of the Bloomberg Terminal?...
#   A1: The Bloomberg Terminal seamlessly integrates data, news, and analytics, providing transparent and re...
#   Q2: How does the Bloomberg keyboard assist in accessing information quickly on the Terminal?...
#   A2: The red stop keys, green action keys, and yellow market sector keys help access information swiftly,...
#
# --- Processing Chunk 3/42 ---
# Chunk length: 924 characters
# Chunk preview: •  Load securities. Example — IBM US <EQUITY> <GO>
# •  Access market sector menus. Example — <CORP> <GO>
# The Escape or Cancel key allows you to exit t...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": [
# 	{
# 	"question": "How can I access market sector menus on the Bloomberg Terminal?",
# 	"answer": "You can access market sector menus by typing <CORP> in the command line and pressing the Enter key."
# 	},
# 	{
# 	"question": "What is the purpose of the <GO> or Enter key on the Bloomberg Terminal?",
# 	"answer": "The <GO> or Enter key executes the command typed in the command line, allowing you to execute actions on the terminal."
# 	}
# ]}
#
#
# --- End of response ---
# ✅ Successfully generated 2 Q&A pairs for chunk 3
#   Q1: How can I access market sector menus on the Bloomberg Terminal?...
#   A1: You can access market sector menus by typing <CORP> in the command line and pressing the Enter key....
#   Q2: What is the purpose of the <GO> or Enter key on the Bloomberg Terminal?...
#   A2: The <GO> or Enter key executes the command typed in the command line, allowing you to execute action...
#
# --- Processing Chunk 4/42 ---
# Chunk length: 971 characters
# Chunk preview: Note — If you have problems locating the application on the computer, consult your Information Technology
# department for guidance on installation and...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": [
#     {"question": "How do I locate the Bloomberg application on my computer if it's not easily accessible?", "answer": "Consult your Information Technology department for guidance on installation and configuration."},
#     {"question": "What steps should I take to open the Bloomberg Terminal application on Windows?", "answer": "From the Windows Start menu, select START > All Programs > Bloomberg > BLOOMBERG."},
#     {"question": "What appears on my desktop once I've successfully opened the Bloomberg Terminal application?", "answer": "A Bloomberg panel (“window”) appears on your desktop."}
# ]}
# --- End of response ---
# ✅ Successfully generated 3 Q&A pairs for chunk 4
#   Q1: How do I locate the Bloomberg application on my computer if it's not easily accessible?...
#   A1: Consult your Information Technology department for guidance on installation and configuration....
#   Q2: What steps should I take to open the Bloomberg Terminal application on Windows?...
#   A2: From the Windows Start menu, select START > All Programs > Bloomberg > BLOOMBERG....
#
# --- Processing Chunk 5/42 ---
# Chunk length: 977 characters
# Chunk preview: •  Press <GO>.
# Up to four Bloomberg panels or windows appear on your computer desktop with default
# “wake-up” screens.
# The Bloomberg Terminal
# Getting ...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [] }
#
#
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 5
#
# --- Processing Chunk 6/42 ---
# Chunk length: 920 characters
# Chunk preview: loaded securities, with the current loaded security visible. The right side features icons to help
# you perform key tasks, including exporting data, v...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": []}
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 6
#
# --- Processing Chunk 7/42 ---
# Chunk length: 994 characters
# Chunk preview: sectors, regions and more.
# Each function is accessed by typing in its unique mnemonic (a short, memorable name) and then
# pressing the <GO> key.
# Exam...
# --- Calling model: ollama/llama3.1:8b ---
# {
#   "generated": [
#     {
#       "question": "What are the main types of functions available in Bloomberg Terminal?",
#       "answer": "There are two types of functions: non-security functions and security-specific functions."
#     },
#     {
#       "question": "How do I access a function using its mnemonic?",
#       "answer": "To access a function, type in its unique mnemonic and press the <GO> key."
#     },
#     {
#       "question": "What is an example of a non-security function in Bloomberg Terminal?",
#       "answer": "WEI (World Equity Indices analysis) is an example of a non-security function that provides information for dozens of equity indices on one screen."
#     },
#     {
#       "question": "How do I determine the type of function based on its requirements?",
#       "answer": "Non-security functions provide information or analysis on an entire market sector and do not require a loaded security, while security-specific functions analyze a loaded security."
#     },
#     {
#       "question": "What is required to run the GP (Graph Price) function in Bloomberg Terminal?",
#       "answer": "You must load a security before graphing its price using the GP function."
#     }
#   ]
# }
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 7
#   Q1: What are the main types of functions available in Bloomberg Terminal?...
#   A1: There are two types of functions: non-security functions and security-specific functions....
#   Q2: How do I access a function using its mnemonic?...
#   A2: To access a function, type in its unique mnemonic and press the <GO> key....
#
# --- Processing Chunk 8/42 ---
# Chunk length: 973 characters
# Chunk preview: Example — GP (Graph Price) is a security-specific function
# because you must specify a security before graphing its
# price. You must load a security ...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 8
#
# --- Processing Chunk 9/42 ---
# Chunk length: 953 characters
# Chunk preview: Example — You want to find a function that analyzes inflation.
# Functions & securities
# Getting started on the Bloomberg Terminal.
# 7
# Working with securi...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": []}
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 9
#
# --- Processing Chunk 10/42 ---
# Chunk length: 991 characters
# Chunk preview: load a different security.
# Loading securities
# There are three main ways to load a security — depending on
# whether or not you know the security’s tick...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [ { "question": "How can you load a security by its ticker symbol on Bloomberg Terminal?", "answer": "You can enter the ticker symbol in the command line or press the yellow market sector key corresponding to the security type and then press <GO>." }, { "question": "What are the steps to load a security if you know its CUSIP, ISIN, or BBGID number on Bloomberg Terminal?", "answer": "You can enter the security identification number in the command line or press the yellow market sector key corresponding to the security type and then press <GO>." }, { "question": "How do you load a security if you don't know its ticker symbol but have an identification number for it on Bloomberg Terminal?", "answer": "You can enter the security identification number in the command line, select the appropriate market sector key, and press <GO> to load the security." } ] }
# --- End of response ---
# ✅ Successfully generated 3 Q&A pairs for chunk 10
#   Q1: How can you load a security by its ticker symbol on Bloomberg Terminal?...
#   A1: You can enter the ticker symbol in the command line or press the yellow market sector key correspond...
#   Q2: What are the steps to load a security if you know its CUSIP, ISIN, or BBGID number on Bloomberg Term...
#   A2: You can enter the security identification number in the command line or press the yellow market sect...
#
# --- Processing Chunk 11/42 ---
# Chunk length: 973 characters
# Chunk preview: •  Press the <GO> key.
# The security appears as the loaded security in the active panel’s
# toolbar and a categorized menu of security-specific analysis...
# --- Calling model: ollama/llama3.1:8b ---
# {
# "generated": [
# {
# "question": "What is the purpose of pressing the <GO> key in Bloomberg Terminal?",
# "answer": "Pressing the <GO> key loads the specified security and displays a categorized menu of security-specific analysis functions."
# },
# {
# "question": "How can you find a specific security if you don't know its ticker or identification number?",
# "answer": "You can use the Autocomplete feature by typing a keyword for the financial instrument in the command line, selecting from the suggested securities list."
# }
# ]
# }
# --- End of response ---
# ✅ Successfully generated 2 Q&A pairs for chunk 11
#   Q1: What is the purpose of pressing the <GO> key in Bloomberg Terminal?...
#   A1: Pressing the <GO> key loads the specified security and displays a categorized menu of security-speci...
#   Q2: How can you find a specific security if you don't know its ticker or identification number?...
#   A2: You can use the Autocomplete feature by typing a keyword for the financial instrument in the command...
#
# --- Processing Chunk 12/42 ---
# Chunk length: 909 characters
# Chunk preview: instrument you want to analyze.
# As you type, Autocomplete provides a list of suggested securities.
# •  Select the security you want to load from the li...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [ { "question": "What is the purpose of Autocomplete in the Bloomberg Terminal?", "answer": "Autocomplete provides a list of suggested securities as you type, making it easy to find the security or function you want." }, { "question": "How does one select a security from the list provided by Autocomplete?", "answer": "To select a security, simply choose it from the suggested listings that appear as you type." }, { "question": "What happens after selecting a security with Autocomplete?", "answer": "The selected security appears as the loaded security in the active panel's toolbar and a categorized menu of analysis functions becomes available." }, { "question": "Can you describe how Bloomberg Terminal's Basic Search (Autocomplete) works?", "answer": "To use Basic Search, type a term in the command line at the top of the active panel; as you type, Autocomplete displays suggested listings that can be picked from to either load a security or run a function." }, { "question": "What is the difference between using Auto-complete and Full search on the Bloomberg Terminal?", "answer": "Auto-complete offers instant suggestions based on typed input, whereas full search provides an in-depth query for more specific results." } ] }
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 12
#   Q1: What is the purpose of Autocomplete in the Bloomberg Terminal?...
#   A1: Autocomplete provides a list of suggested securities as you type, making it easy to find the securit...
#   Q2: How does one select a security from the list provided by Autocomplete?...
#   A2: To select a security, simply choose it from the suggested listings that appear as you type....
#
# --- Processing Chunk 13/42 ---
# Chunk length: 992 characters
# Chunk preview: 1. Autocomplete
# suggested listings.
# 2. Click to select a
# suggested function.
# 1
# 2
# Navigation
# Getting started on the Bloomberg Terminal.
# 10
# Full sea...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [] }
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 13
#
# --- Processing Chunk 14/42 ---
# Chunk length: 960 characters
# Chunk preview: Search
# HL search results
# Navigation
# Getting started on the Bloomberg Terminal.
# 11
# Browsing menus
# About menus
# All Bloomberg functions are organized by ...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [ { "question": "What is the primary way users can navigate menus in Bloomberg Terminal?", "answer": "Users can browse menus to discover more about the analysis and information the Bloomberg Terminal offers." }, { "question": "How are menus organized on the Bloomberg Terminal?", "answer": "All Bloomberg functions are organized by menus that are classified by market sector or product type, forming a hierarchy from individual functions up to the Bloomberg Home menu." }, { "question": "What key combinations can be used to access menus in Bloomberg Terminal?", "answer": "There are three ways to access menus: using the Menu button, pressing the <MENU> key, or using the Yellow key. Additionally, users can use the menu key from any function to access related functions and their corresponding menus." }, { "question": "What is the role of the Menu button in navigating Bloomberg Terminal?", "answer": "The Menu button allows users to access a menu of related functions, providing an alternative method to accessing menus using keyboard shortcuts or the Yellow key. Once accessed, clicking the <MENU> key opens the menu further." }, { "question": "How do you access individual functions within a menu hierarchy in Bloomberg Terminal?", "answer": "Users can navigate through the menu hierarchy by selecting specific paths, such as Main Menu > Equities > Analyze FORD MOTOR CO Equity > Company Analysis > Financial Analysis > FA, to reach individual functions." } ] }
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 14
#   Q1: What is the primary way users can navigate menus in Bloomberg Terminal?...
#   A1: Users can browse menus to discover more about the analysis and information the Bloomberg Terminal of...
#   Q2: How are menus organized on the Bloomberg Terminal?...
#   A2: All Bloomberg functions are organized by menus that are classified by market sector or product type,...
#
# --- Processing Chunk 15/42 ---
# Chunk length: 998 characters
# Chunk preview: From any function, click the Menu button on the toolbar or
# press the <MENU> key to access a menu of related functions.
# Once you access the menu, cli...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
#
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 15
#
# --- Processing Chunk 16/42 ---
# Chunk length: 996 characters
# Chunk preview: Bloomberg menus are intuitively organized to speed
# your search efforts.
# Menu breadcrumbs
# These show your path in the overall menu hierarchy
# and ena...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [
#         {
#             "question": "How do I navigate through Bloomberg menus to speed up my search efforts?",
#             "answer": "Bloomberg menus are intuitively organized, and you can use menu breadcrumbs to show your path in the overall menu hierarchy and navigate backward and forward."
#         },
#         {
#             "question": "What is the purpose of categories and functions in Bloomberg menus?",
#             "answer": "Menus organize functions under categories, allowing you to click on category headings followed by “>” to see the next menu in the hierarchy."
#         },
#         {
#             "question": "How do I close a menu on the Bloomberg Terminal?",
#             "answer": "You can close a menu by clicking <Cancel> X located in the upper right-hand corner of the menu."
#         },
#         {
#             "question": "What does the red bar at the top of each function represent in the Bloomberg Terminal?",
#             "answer": "The red bar includes the function’s title at the right and provides drop-down menus and buttons to help you perform key tasks, as well as a page number indicator."
#         },
#         {
#             "question": "What do amber-colored fields indicate on the Bloomberg Terminal screen?",
#             "answer": "Amber fields represent areas on the screen that you can change, including editable-form elements, text input areas, and drop-down lists."
#         }
#     ] }
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 16
#   Q1: How do I navigate through Bloomberg menus to speed up my search efforts?...
#   A1: Bloomberg menus are intuitively organized, and you can use menu breadcrumbs to show your path in the...
#   Q2: What is the purpose of categories and functions in Bloomberg menus?...
#   A2: Menus organize functions under categories, allowing you to click on category headings followed by “>...
#
# --- Processing Chunk 17/42 ---
# Chunk length: 976 characters
# Chunk preview: Amber-colored fields represent editable-form elements, text
# and data input areas and drop-down lists.
# Clickable areas
# Moving your cursor over a click...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 17
#
# --- Processing Chunk 18/42 ---
# Chunk length: 961 characters
# Chunk preview: 3. Number <GO>
# 4. Clickable area
# 3
# 4
# 1
# 2
# Navigating functions
# Bloomberg functions use common screen elements that work in similar ways. Once you learn...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": [{
#
#     "question": "What is the primary function of the Bloomberg Terminal?",
#     "answer": "The Bloomberg Terminal is used for navigating various functions and using common screen elements."
#
# }, {
#
#     "question": "How do I initiate the Equity Screening process on the Bloomberg Terminal?",
#     "answer": "You start by entering EQS <GO> to open the Equity Screening screen."
#
# }, {
#
#     "question": "What is the purpose of the Add Criteria section in the Equity Screening process?",
#     "answer": "The Add Criteria section allows you to refine your search with more data-driven criteria, such as industry classifications and fundamentals."
#
# }, {
#
#     "question": "How do I select specific criterion fields for use in the Build/Edit Screen tab?",
#     "answer": "You can identify these by using the category tree or Search field at the left of the Browse Fields window, then click the Select button to add them to your criteria."
#
# }, {
#
#     "question": "What is the significance of understanding common screen elements on the Bloomberg Terminal?",
#     "answer": "Once you learn about these elements, you can use any function on the terminal as they work in similar ways."
#
# }]}
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 18
#   Q1: What is the primary function of the Bloomberg Terminal?...
#   A1: The Bloomberg Terminal is used for navigating various functions and using common screen elements....
#   Q2: How do I initiate the Equity Screening process on the Bloomberg Terminal?...
#   A2: You start by entering EQS <GO> to open the Equity Screening screen....
#
# --- Processing Chunk 19/42 ---
# Chunk length: 989 characters
# Chunk preview: updates with the name of the selected criterion field
# and additional fields that allow you to set a condition(s)
# for the selected criterion.
# •  Ent...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [] }
#
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 19
#
# --- Processing Chunk 20/42 ---
# Chunk length: 919 characters
# Chunk preview: The following is a quick-start overview for using EQS.
# Step 2
# Use the Screening Criteria section to define preliminary
# search criteria.
# •  Click a ca...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [
#   {
#     "question": "How do I define preliminary search criteria in EQS?",
#     "answer": "You can use the Screening Criteria section to define preliminary search criteria. To do this, click a category, drag and drop the appropriate criterion from the window, and click the Update button."
#   },
#   {
#     "question": "What is involved in performing analysis on a company using the Bloomberg Terminal?",
#     "answer": "Performing analysis involves selecting screening criteria and updating them to get the complete breadth and depth of information about a company."
#   },
#   {
#     "question": "How do I save my selected criterion for future use in EQS?",
#     "answer": "Once you click the Update button, your selected criterion is saved, and the window closes. The Selected Screening Criteria section at the bottom updates with your selected criterion and count of company matches."
#   },
#   {
#     "question": "What is the role of categories in defining search criteria on the Bloomberg Terminal?",
#     "answer": "Clicking a category allows you to select options for that category, which can be dragged and dropped into the Included Options or Excluded Options section for your preliminary search criteria."
#   },
#   {
#     "question": "How does one navigate the Bloomberg Terminal for analysis purposes?",
#     "answer": "Navigation involves understanding the overall logic of the terminal, allowing users to intuitively discover the complete breadth and depth of information available on it."
#   }
# ] }
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 20
#   Q1: How do I define preliminary search criteria in EQS?...
#   A1: You can use the Screening Criteria section to define preliminary search criteria. To do this, click ...
#   Q2: What is involved in performing analysis on a company using the Bloomberg Terminal?...
#   A2: Performing analysis involves selecting screening criteria and updating them to get the complete brea...
#
# --- Processing Chunk 21/42 ---
# Chunk length: 905 characters
# Chunk preview: of the Bloomberg Terminal. With that information, the complete breadth and depth of
# information on Bloomberg are intuitively and completely discovera...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 21
#
# --- Processing Chunk 22/42 ---
# Chunk length: 971 characters
# Chunk preview: the full range of analysis options.
# •  Enter the mnemonic for the specific function you want to run,
# then press <GO>.
# The analysis function runs on ...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [] }
#
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 22
#
# --- Processing Chunk 23/42 ---
# Chunk length: 983 characters
# Chunk preview: Note — To access a function’s Help Page (a comprehensive user
# guide), press the <HELP> key once.
# For cheatsheets that provide lists of popular analys...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [ { "question": "How do you access a function's Help Page on the Bloomberg Terminal?", "answer": "Press the <HELP> key once." }, { "question": "What is the purpose of entering BU <GO> and clicking Access Training Documents link?", "answer": "It provides lists of popular analysis functions for specific security types." }, { "question": "How do you load different types of securities or indices on the Bloomberg Terminal?", "answer": "Use the Autocomplete feature or enter a ticker and press the yellow key." }, { "question": "What is the significance of the Functions & securities and Navigation sections in this guide?", "answer": "They describe the overall logic and navigation of the Bloomberg Terminal, allowing access to its breadth and depth of information." }, { "question": "How do you analyze an index, bond, or currency on the Bloomberg Terminal?", "answer": "Load the security or index using Autocomplete or by entering a ticker and pressing the yellow key; then run analysis functions as needed." } ] }
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 23
#   Q1: How do you access a function's Help Page on the Bloomberg Terminal?...
#   A1: Press the <HELP> key once....
#   Q2: What is the purpose of entering BU <GO> and clicking Access Training Documents link?...
#   A2: It provides lists of popular analysis functions for specific security types....
#
# --- Processing Chunk 24/42 ---
# Chunk length: 949 characters
# Chunk preview: Examples
# SPX <INDEX> <GO>
# S&P 500 index
# USURTOT <INDEX> <GO>
# Index tracking the
# U.S. unemployment rate
# EUR <CURNCY> <GO>
# Euro spot
# F 12 07/16/...
# --- Calling model: ollama/llama3.1:8b ---
# {
#   "generated": [
#     {
#       "question": "What is the mnemonic to run the analysis function on a loaded security?",
#       "answer": "You can enter the mnemonic for the function you want to run, then press <GO>. For cheatsheets that provide lists of popular analysis functions for specific security types, enter BPS <GO>, then click through to your chosen subject."
#     },
#     {
#       "question": "How do I access the full range of analysis options for a loaded security?",
#       "answer": "You can click on a category or function from the menu to explore the full range of analysis options."
#     },
#     {
#       "question": "What type of securities may not work with specific functions, such as Yield Analysis (YA)?",
#       "answer": "Functions that work for one type of security may not work for different types of securities. For example, the YA function allows you to value a bond but may not work if you load an index."
#     },
#     {
#       "question": "What is the purpose of BPS <GO>?",
#       "answer": "BPS <GO> provides lists of popular analysis functions for specific security types and allows you to click through to your chosen subject."
#     }
#   ]
# }
# --- End of response ---
# ✅ Successfully generated 4 Q&A pairs for chunk 24
#   Q1: What is the mnemonic to run the analysis function on a loaded security?...
#   A1: You can enter the mnemonic for the function you want to run, then press <GO>. For cheatsheets that p...
#   Q2: How do I access the full range of analysis options for a loaded security?...
#   A2: You can click on a category or function from the menu to explore the full range of analysis options....
#
# --- Processing Chunk 25/42 ---
# Chunk length: 991 characters
# Chunk preview: of security does not work for a different type of security.
# For example, the Yield Analysis (YA) function allows you
# to value a bond. If you load an...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
#
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 25
#
# --- Processing Chunk 26/42 ---
# Chunk length: 981 characters
# Chunk preview: Start > All Programs > Bloomberg > Install Excel Add-in.
# An Installing Bloomberg Excel Add-in dialog box appears.
# Step 2
# Click Install. A confirmation...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [
#    { "question": "How do you access the Bloomberg Excel Add-in in Microsoft Excel?",
#      "answer": "You can find the Bloomberg Excel Add-in on Excel's taskbar once it has been installed." },
#    { "question": "What is the main purpose of the Bloomberg Excel Add-in?",
#      "answer": "The Bloomberg Excel Add-in delivers Bloomberg data into a Microsoft Excel spreadsheet for custom analysis and calculations." },
#    { "question": "What information is required to use the Bloomberg Excel Add-in effectively?",
#      "answer": "All data must remain on a licensed Bloomberg workstation, and you need access to the Bloomberg software." },
#    { "question": "How can you download data from the Bloomberg Terminal to Excel using the add-in?",
#      "answer": "You can use one of the Bloomberg Data Wizard options within the add-in for easy data downloading." },
#    { "question": "What should you do if you are unable to install the Bloomberg Excel Add-in on your computer?",
#      "answer": "Consult your Information Technology team regarding administration rights to the computer." }
# ]}
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 26
#   Q1: How do you access the Bloomberg Excel Add-in in Microsoft Excel?...
#   A1: You can find the Bloomberg Excel Add-in on Excel's taskbar once it has been installed....
#   Q2: What is the main purpose of the Bloomberg Excel Add-in?...
#   A2: The Bloomberg Excel Add-in delivers Bloomberg data into a Microsoft Excel spreadsheet for custom ana...
#
# --- Processing Chunk 27/42 ---
# Chunk length: 994 characters
# Chunk preview: Getting started on the Bloomberg Terminal.
# 18
# Bloomberg Data Wizard
# The easiest way to download data to Excel via the Bloomberg
# Excel Add-in is to us...
# --- Calling model: ollama/llama3.1:8b ---
# {
#   "generated": [
#     {
#       "question": "What are the two primary ways to access the Bloomberg Data Wizard?",
#       "answer": "The two primary ways to access the Bloomberg Data Wizard are through the Real-Time/Historical icon or the Financials/Estimates icon on the Bloomberg tab of the Excel spreadsheet."
#     },
#     {
#       "question": "How do I choose the correct data type option in the Bloomberg Data Wizard?",
#       "answer": "You can display a blurb describing the type of data available with each Wizard option by moving your mouse over each of the data type icons."
#     },
#     {
#       "question": "What is the purpose of using the Financials/Estimates icon in the Bloomberg Data Wizard?",
#       "answer": "The Financials/Estimates icon allows you to download values from financial statements and/or earnings data into Excel via the Bloomberg Fundamental Analysis Wizard window."
#     },
#     {
#       "question": "Can you describe the process of accessing data through the Bloomberg Data Wizard?",
#       "answer": "To access data, choose an option from the Import group on the Bloomberg tab in Excel, click on the desired icon, and then select the data type option to download the data into a spreadsheet."
#     },
#     {
#       "question": "What is the role of the Real-Time/Historical icon in the Bloomberg Data Wizard?",
#       "answer": "The Real-Time/Historical icon enables you to download most forms of data into Excel via the Bloomberg Data Wizard window with four data type options."
#     }
#   ]
# }
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 27
#   Q1: What are the two primary ways to access the Bloomberg Data Wizard?...
#   A1: The two primary ways to access the Bloomberg Data Wizard are through the Real-Time/Historical icon o...
#   Q2: How do I choose the correct data type option in the Bloomberg Data Wizard?...
#   A2: You can display a blurb describing the type of data available with each Wizard option by moving your...
#
# --- Processing Chunk 28/42 ---
# Chunk length: 980 characters
# Chunk preview: with each Wizard option.
# Step 3
# Click on the icon representing the type of data you want
# to download.
# Step 1 of the Wizard appears.
# Step 4
# Follow the...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 28
#
# --- Processing Chunk 29/42 ---
# Chunk length: 945 characters
# Chunk preview: to Excel. The wizards write the Bloomberg API formulas for you.
# You can, however, write the formulas yourself if you need more
# flexibility than the ...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 29
#
# --- Processing Chunk 30/42 ---
# Chunk length: 949 characters
# Chunk preview: Exporting data
# Getting started on the Bloomberg Terminal.
# 19
# Exporting data
# Drag & drop
# Some functions display a drag and drop icon in the top right c...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 30
#
# --- Processing Chunk 31/42 ---
# Chunk length: 992 characters
# Chunk preview: from Bloomberg.
# To display a list of export options, click on the Export icon
# at the top right of a panel’s toolbar.
# Getting started on the Bloomberg...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": [ {"question": "Where can I find a list of export options on the Bloomberg Terminal?", "answer": "Click on the Export icon at the top right of a panel’s toolbar."}, {"question": "What is the best next step to get acquainted with the Bloomberg Terminal?", "answer": "Complete the certification course: Bloomberg Market Concepts (BMC)."}, {"question": "How long does the Bloomberg Market Concepts (BMC) certification course take to complete?", "answer": "The BMC course is an 8-hour, self-paced e-learning course."}, {"question": "What topics are covered in the Bloomberg Market Concepts (BMC) certification course?", "answer": "The BMC course covers more than 70 Terminal functions, including Economics, Currencies, Fixed Income and Equities modules."}, {"question": "What benefits can I expect to gain from taking the Bloomberg Market Concepts (BMC) certification course?", "answer": "By taking BMC, you will learn the language of finance, supplement your university learnings with practical knowledge of the markets, and familiarize yourself with more than 70 Bloomberg Terminal functions."} ] }
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 31
#   Q1: Where can I find a list of export options on the Bloomberg Terminal?...
#   A1: Click on the Export icon at the top right of a panel’s toolbar....
#   Q2: What is the best next step to get acquainted with the Bloomberg Terminal?...
#   A2: Complete the certification course: Bloomberg Market Concepts (BMC)....
#
# --- Processing Chunk 32/42 ---
# Chunk length: 964 characters
# Chunk preview: •  Supplement your university learnings with practical
# knowledge of the markets.
# •  Familiarize yourself with more than 70 Bloomberg
# Terminal func...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [] }
#
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 32
#
# --- Processing Chunk 33/42 ---
# Chunk length: 987 characters
# Chunk preview: homepage with links to training resources, including training
# documents and video tutorials.
# Help pages
# Each function has a comprehensive, searchable...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
#
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 33
#
# --- Processing Chunk 34/42 ---
# Chunk length: 968 characters
# Chunk preview: (simply click on the rep’s name)
# Getting help & learning more
# There are a variety of ways to get help using the Bloomberg Terminal.
# Getting started on...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": [
#     {
#       "question": "What are some ways to get help when using the Bloomberg Terminal?",
#       "answer": "There are various options, including getting certified, visiting the Help and Learning Center, locating cheatsheets and videos, searching for webinars, or contacting BMC."
#     },
#     {
#       "question": "How can I get started on the Bloomberg Terminal if I'm new to it?",
#       "answer": "You can begin by reviewing the training resources available, such as getting certified through BMC and accessing the Help and Learning Center."
#     },
#     {
#       "question": "What features does the Bloomberg Terminal offer for charting securities and technical studies?",
#       "answer": "You can use function GP to chart securities and technical studies on the Bloomberg Terminal."
#     },
#     {
#       "question": "How do I visualize and compare the performance of two securities using the Bloomberg Terminal?",
#       "answer": "Function HS allows you to visualize and compare the performance of two securities."
#     },
#     {
#       "question": "What tool can be used to standardize and manipulate economic data on the Bloomberg Terminal?",
#       "answer": "ECWB is a function that enables you to standardize and manipulate economic data."
#     }
#   ]}
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 34
#   Q1: What are some ways to get help when using the Bloomberg Terminal?...
#   A1: There are various options, including getting certified, visiting the Help and Learning Center, locat...
#   Q2: How can I get started on the Bloomberg Terminal if I'm new to it?...
#   A2: You can begin by reviewing the training resources available, such as getting certified through BMC a...
#
# --- Processing Chunk 35/42 ---
# Chunk length: 996 characters
# Chunk preview: economic data.
# Commodities
# BGAS
# See pricing for the North American natural
# gas spot market.
# BOIL
# Get a full picture of global oil & refined
# prod...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 35
#
# --- Processing Chunk 36/42 ---
# Chunk length: 985 characters
# Chunk preview: Leverage QuickTakes to put important news events
# in context.
# ANR
# See analyst recommendations and price targets
# for an equity.
# Currencies
# FXFC
# A...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [] }
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 36
#
# --- Processing Chunk 37/42 ---
# Chunk length: 991 characters
# Chunk preview: Getting started on the Bloomberg Terminal.
# 23
# Functions
# Economics
# FED
# Monitor the activities of the U.S. Federal Reserve bank.
# CENB
# Access portals ...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 37
#
# --- Processing Chunk 38/42 ---
# Chunk length: 973 characters
# Chunk preview: RV
# Compare a stock to its peers across various metrics.
# EQRV
# Evaluate whether a company is fairly valued relative
# to peers.
# CM
# Monitor the key e...
# --- Calling model: ollama/llama3.1:8b ---
# {"generated": []}
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 38
#
# --- Processing Chunk 39/42 ---
# Chunk length: 997 characters
# Chunk preview: to a country’s debt.
# WB
# Monitor sovereign bond yields, spreads
# and performance.
# CRPR
# Assess the creditworthiness of an issuer
# or fixed income se...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [] }
#
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 39
#
# --- Processing Chunk 40/42 ---
# Chunk length: 994 characters
# Chunk preview: TWTR
# Search for Twitter news on Bloomberg.
# CN
# See top news on a specific company.
# FIRS
# Read summarized news stories to track
# market-moving news.
# ...
# --- Calling model: ollama/llama3.1:8b ---
# {
#   "generated": [
#     {
#       "question": "What feature allows you to search for news on a specific company?",
#       "answer": "CN allows you to see top news on a specific company."
#     },
#     {
#       "question": "How can I track market-moving news with summarized stories?",
#       "answer": "You can read summarized news stories with FIRS to track market-moving news."
#     },
#     {
#       "question": "What is the benefit of setting up email alerts for news on followed companies?",
#       "answer": "Setting up email alerts for news on the companies you follow using SALT allows you to stay updated."
#     },
#     {
#       "question": "What feature enables users to create, manage, and share portfolios for analysis in PORT?",
#       "answer": "PRTU allows users to create, manage, and share their portfolios for analysis in PORT."
#     },
#     {
#       "question": "How can you upload your portfolios, benchmarks, and custom data for analysis in PORT?",
#       "answer": "You can use BBU to upload your portfolios, benchmarks, and custom data for analysis in PORT."
#     }
#   ]
# }
# --- End of response ---
# ✅ Successfully generated 5 Q&A pairs for chunk 40
#   Q1: What feature allows you to search for news on a specific company?...
#   A1: CN allows you to see top news on a specific company....
#   Q2: How can I track market-moving news with summarized stories?...
#   A2: You can read summarized news stories with FIRS to track market-moving news....
#
# --- Processing Chunk 41/42 ---
# Chunk length: 983 characters
# Chunk preview: your Bloomberg.net email account.
# MRUL
# Manage message rules, including forwarding emails
# to your Bloomberg.net email to your personal email
# accoun...
# --- Calling model: ollama/llama3.1:8b ---
# { "generated": [] }
# --- End of response ---
# ✅ Successfully generated 0 Q&A pairs for chunk 41
#
# --- Processing Chunk 42/42 ---
# Chunk length: 716 characters
# Chunk preview: to mortgages — all seamlessly integrated with
# on-demand multimedia content, extensive
# electronic-trading capabilities and a superior
# communicati...
# --- Calling model: ollama/llama3.1:8b ---
# {
#     "generated": [
#         {
#             "question": "What features does the Bloomberg Terminal offer?",
#             "answer": "Seamless integration with on-demand multimedia content, electronic-trading capabilities, and a superior communications network."
#         },
#         {
#             "question": "How can I access additional information on the Bloomberg Terminal?",
#             "answer": "Press the <HELP> key twice to view further details."
#         }
#     ]
# }
#
#
# --- End of response ---
# ✅ Successfully generated 2 Q&A pairs for chunk 42
#   Q1: What features does the Bloomberg Terminal offer?...
#   A1: Seamless integration with on-demand multimedia content, electronic-trading capabilities, and a super...
#   Q2: How can I access additional information on the Bloomberg Terminal?...
#   A2: Press the <HELP> key twice to view further details....

# %%
# Show final statistics
successful_chunks = len([k for k, v in dataset.items() if v.get("generated")])
total_qa_pairs = sum(len(v.get("generated", [])) for v in dataset.values())


print(f"\n{Fore.GREEN}Generation complete!{Style.RESET_ALL}")
print(f"Successfully processed: {successful_chunks}/{len(chunks)} chunks")
print(f"Total Q&A pairs generated: {total_qa_pairs}")
# Out:
# Generation complete!
# Successfully processed: 20/42 chunks
# Total Q&A pairs generated: 85
